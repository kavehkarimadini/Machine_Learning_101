# %%
import pandas as pd

# %%
data=pd.read_csv('stack_servey/survey_results_public.csv',index_col='Respondent')

# %%
data
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88883 entries, 1 to 88863
# Data columns (total 84 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   MainBranch              88331 non-null  object
#  1   Hobbyist                88883 non-null  object
#  2   OpenSourcer             88883 non-null  object
#  3   OpenSource              86842 non-null  object
#  4   Employment              87181 non-null  object
#  5   Country                 88751 non-null  object
#  6   Student                 87014 non-null  object
#  7   EdLevel                 86390 non-null  object
#  8   UndergradMajor          75614 non-null  object
#  9   EduOther                84260 non-null  object
#  10  OrgSize                 71791 non-null  object
#  11  DevType                 81335 non-null  object
#  12  YearsCode               87938 non-null  object
#  13  Age1stCode              87634 non-null  object
# ...

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
schema=pd.read_csv('stack_servey/survey_results_schema.csv',index_col='Column')

# %%
schema.loc['Hobbyist','QuestionText']
# Out:
# 'Do you code as a hobby?'

# %%
schema.sort_index(ascending=False,inplace=True)

# %%
schema
# Out:
#                                                              QuestionText
# Column
# YearsCodePro            How many years have you coded professionally (...
# YearsCode               Including any education, how many years have y...
# WorkWeekHrs              On average, how many hours per week do you work?
# WorkRemote                                How often do you work remotely?
# WorkPlan                          How structured or planned is your work?
# WorkLoc                                   Where would you prefer to work?
# WorkChallenge           Of these options, what are your greatest chall...
# WelcomeChange           Compared to last year, how welcome do you feel...
# WebFrameWorkedWith      Which of the following web frameworks have you...
# WebFrameDesireNextYear  Which of the following web frameworks have you...
# UnitTests               Does your company regularly employ unit tests ...
# UndergradMajor          What was your main or most important field of ...
# ...

# %%
data.head(10)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# 6           I am not primarily a developer, but I write co...      Yes
# 7                              I am a developer by profession       No
# 8                                 I code primarily as a hobby      Yes
# 9                              I am a developer by profession      Yes
# 10                             I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# ...

# %%
data.tail(10)
# Out:
#            MainBranch Hobbyist  \
# Respondent
# 88062             NaN       No
# 88076             NaN       No
# 88182             NaN      Yes
# 88212             NaN       No
# 88282             NaN      Yes
# 88377             NaN      Yes
# 88601             NaN       No
# 88802             NaN       No
# 88816             NaN       No
# 88863             NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 88062                                                   Never
# 88076                                                   Never
# 88182                              Once a month or more often
# 88212                                 Less than once per year
# 88282                              Once a month or more often
# 88377       Less than once a month but more than once per ...
# 88601                                                   Never
# 88802                                                   Never
# ...

# %%
people={
    'first_name':['kaveh','arash','ali'],
    'last_name':['karimadini','karimadini','karimadini'],
    'age':['20','20','38']
}
dpeople=pd.DataFrame(people)

# %%
dpeople
# Out:
#   first_name   last_name age
# 0      kaveh  karimadini  20
# 1      arash  karimadini  20
# 2        ali  karimadini  38

# %%
dpeople['age']
# Out:
# 0    20
# 1    20
# 2    38
# Name: age, dtype: object

# %%
dpeople.age
# Out:
# 0    20
# 1    20
# 2    38
# Name: age, dtype: object

# %%
type(dpeople['age'])
# Out:
# pandas.core.series.Series

# %%
dpeople[['first_name','age']]
# Out:
#   first_name age
# 0      kaveh  20
# 1      arash  20
# 2        ali  38

# %%
dpeople.columns
# Out:
# Index(['first_name', 'last_name', 'age'], dtype='object')

# %%
dpeople.iloc[0]
# Out:
# first_name         kaveh
# last_name     karimadini
# age                   20
# Name: 0, dtype: object

# %%
dpeople.iloc[[0,1],[0,2]]
# Out:
#   first_name age
# 0      kaveh  20
# 1      arash  20

# %%
dpeople.iloc[[0,1],0]
# Out:
# 0    kaveh
# 1    arash
# Name: first_name, dtype: object

# %%
dpeople.loc[1]
# Out:
# first_name         arash
# last_name     karimadini
# age                   20
# Name: 1, dtype: object

# %%
dpeople.loc[[0,1]]
# Out:
#   first_name   last_name age
# 0      kaveh  karimadini  20
# 1      arash  karimadini  20

# %%
dpeople.loc[[0,1],'age']
# Out:
# 0    20
# 1    20
# Name: age, dtype: object

# %%
dpeople.loc[[0,1],['age','first_name']]
# Out:
#   age first_name
# 0  20      kaveh
# 1  20      arash

# %%
data.shape
# Out:
# (88883, 84)

# %%
data.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
data['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
data['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
data.loc[1]
# Out:
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# DevType                                                                 NaN
# ...

# %%
data.loc[1,'Hobbyist']
# Out:
# 'Yes'

# %%
data.loc[1:5,'Hobbyist':'Employment']
# Out:
#            Hobbyist                 OpenSourcer  \
# Respondent
# 1               Yes                       Never
# 2                No     Less than once per year
# 3               Yes                       Never
# 4                No                       Never
# 5               Yes  Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...
# 5           OSS is, on average, of HIGHER quality than pro...
#
#                                         Employment
# Respondent
# 1           Not employed, and not looking for work
# 2               Not employed, but looking for work
# 3                               Employed full-time
# 4                               Employed full-time
# ...

# %%
dpeople.set_index('first_name',inplace=True)

# %%
dpeople
# Out:
#              last_name age
# first_name
# kaveh       karimadini  20
# arash       karimadini  20
# ali         karimadini  38

# %%
dpeople.index
# Out:
# Index(['kaveh', 'arash', 'ali'], dtype='object', name='first_name')

# %%
dpeople.loc['kaveh','last_name']
# Out:
# 'karimadini'

# %%
dpeople.reset_index(inplace=True)

# %%
dpeople
# Out:
#   first_name   last_name age
# 0      kaveh  karimadini  20
# 1      arash  karimadini  20
# 2        ali  karimadini  38

# %%
filt1=(dpeople['age']=='20')|(dpeople['first_name']=='ali')

# %%
dpeople[~filt1]
# Out:
# Empty DataFrame
# Columns: [first_name, last_name, age]
# Index: []

# %%
dpeople.loc[filt1]
# Out:
#   first_name   last_name age
# 0      kaveh  karimadini  20
# 1      arash  karimadini  20
# 2        ali  karimadini  38

# %%
dpeople.loc[filt1,'age']
# Out:
# 0    20
# 1    20
# 2    38
# Name: age, dtype: object

# %%
salary=(data['ConvertedComp']>70000)

# %%
data.loc[salary,['Country','LanguageWorkedWith','ConvertedComp']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 6                   Canada                                         Java;R;SQL
# 9              New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 13           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                    ...                                                ...
# 88876        United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88877        United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88878        United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88879              Finland                   Bash/Shell/PowerShell;C++;Python
# 88882          Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
# ...

# %%
countries=['United States','Finland','United Kingdom']
filt2=data['Country'].isin(countries)

# %%
data.loc[filt2,'Country']
# Out:
# Respondent
# 1        United Kingdom
# 4         United States
# 13        United States
# 16       United Kingdom
# 22        United States
#               ...
# 83397     United States
# 84539    United Kingdom
# 85642     United States
# 85961    United Kingdom
# 88282     United States
# Name: Country, Length: 27232, dtype: object

# %%
filt3=data['LanguageWorkedWith'].str.contains('Python',na=False)

# %%
data.loc[filt3,'LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %%
dpeople.columns=['name','last','age']

# %%
dpeople.columns=[x.upper() for x in dpeople.columns]
dpeople
# Out:
#     NAME        LAST AGE
# 0  kaveh  karimadini  20
# 1  arash  karimadini  20
# 2    ali  karimadini  38

# %%
dpeople.columns=dpeople.columns.str.replace('A','E')
dpeople
# Out:
#     NEME        LEST EGE
# 0  kaveh  karimadini  20
# 1  arash  karimadini  20
# 2    ali  karimadini  38

# %%
dpeople.rename(columns={'NEME':'first_name','LEST':'last_name','EGE':'age'},inplace=True)
dpeople
# Out:
#   first_name   last_name age
# 0      kaveh  karimadini  20
# 1      arash  karimadini  20
# 2        ali  karimadini  38

# %%
#dpeople[0]=['kaveh','karimodini','21']
dpeople.loc[0]=['kaveh','karimodini','21',]
dpeople
# Out:
#   first_name   last_name age
# 0      kaveh  karimodini  21
# 1      arash  karimadini  20
# 2        ali  karimadini  38

# %%
dpeople.loc[0,'first_name']='abdolgader'
dpeople
# Out:
#    first_name   last_name age
# 0  abdolgader  karimodini  21
# 1       arash  karimadini  20
# 2         ali  karimadini  38

# %%
dpeople.at[0,['first_name','last_name']]=['kaveh','karimadini']
dpeople
# Out:
#   first_name   last_name age
# 0      kaveh  karimadini  21
# 1      arash  karimadini  20
# 2        ali  karimadini  38

# %%
filt4=(dpeople['age']=='20')
#dpeople.loc[filt4,'age']='20'
dpeople[filt4]['first_name']
# Out:
# 1    arash
# Name: first_name, dtype: object

# %%
dpeople['last_name']=dpeople['last_name'].str.lower()
dpeople
# Out:
#   first_name   last_name age
# 0      kaveh  karimadini  21
# 1      arash  karimadini  20
# 2        ali  karimadini  38

# %%
dpeople['last_name'].apply(len)
# Out:
# 0    10
# 1    10
# 2    10
# Name: last_name, dtype: int64

# %%
def up(first_name):
    return first_name.upper()

# %%
dpeople['first_name']=dpeople['first_name'].apply(up)
dpeople
# Out:
#   first_name   last_name age
# 0      KAVEH  karimadini  21
# 1      ARASH  karimadini  20
# 2        ALI  karimadini  38

# %%
dpeople['first_name']=dpeople['first_name'].apply(lambda x: x.lower())
dpeople
# Out:
#   first_name   last_name age
# 0      kaveh  karimadini  21
# 1      arash  karimadini  20
# 2        ali  karimadini  38

# %%
dpeople.apply(len,axis='columns')
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
len(dpeople['age'])
# Out:
# 3

# %%
dpeople.apply(pd.Series.min)
# Out:
# first_name           ali
# last_name     karimadini
# age                   20
# dtype: object

# %%
dpeople.apply(lambda x: x.min())
# Out:
# first_name           ali
# last_name     karimadini
# age                   20
# dtype: object

# %%
dpeople.applymap(len)
# Out:
#    first_name  last_name  age
# 0           5         10    2
# 1           5         10    2
# 2           3         10    2

# %%
dpeople.applymap(str.lower)
# Out:
#   first_name   last_name age
# 0      kaveh  karimadini  21
# 1      arash  karimadini  20
# 2        ali  karimadini  38

# %%
dpeople['first_name'].map({'kaveh':'abdolgader','arash':'abdolaziz'})
# Out:
# 0    abdolgader
# 1     abdolaziz
# 2           NaN
# Name: first_name, dtype: object

# %%
dpeople['first_name']=dpeople['first_name'].replace({'kaveh':'abdolgader','arash':'abdolaziz'})
dpeople
# Out:
#    first_name   last_name age
# 0  abdolgader  karimadini  21
# 1   abdolaziz  karimadini  20
# 2         ali  karimadini  38

# %%
data.rename(columns={'ConvertedComp':'salaryUSD'},inplace=True)

# %%
data['salaryUSD']
# Out:
# Respondent
# 1            NaN
# 2            NaN
# 3         8820.0
# 4        61000.0
# 5            NaN
#           ...
# 88377        NaN
# 88601        NaN
# 88802        NaN
# 88816        NaN
# 88863        NaN
# Name: salaryUSD, Length: 88883, dtype: float64

# %%
data['Hobbyist']=data['Hobbyist'].replace({'Yes':'true','No':'false'})
data
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code     true
# 2                      I am a student who is learning to code    false
# 3           I am not primarily a developer, but I write co...     true
# 4                              I am a developer by profession    false
# 5                              I am a developer by profession     true
# ...                                                       ...      ...
# 88377                                                     NaN     true
# 88601                                                     NaN    false
# 88802                                                     NaN    false
# 88816                                                     NaN    false
# 88863                                                     NaN     true
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
dpeople['full_name']= dpeople['first_name']+' '+dpeople['last_name']
dpeople
# Out:
#    first_name   last_name age              full_name
# 0  abdolgader  karimadini  21  abdolgader karimadini
# 1   abdolaziz  karimadini  20   abdolaziz karimadini
# 2         ali  karimadini  38         ali karimadini

# %%
dpeople.drop(columns=['first_name','last_name'],inplace=True)
dpeople
# Out:
#   age              full_name
# 0  21  abdolgader karimadini
# 1  20   abdolaziz karimadini
# 2  38         ali karimadini

# %%
dpeople[['first','last']]=dpeople['full_name'].str.split(' ',expand=True)
dpeople
# Out:
#   age              full_name       first        last
# 0  21  abdolgader karimadini  abdolgader  karimadini
# 1  20   abdolaziz karimadini   abdolaziz  karimadini
# 2  38         ali karimadini         ali  karimadini

# %%
dpeople.append({'first':'vahid'},ignore_index=True)
# Out:
#    age              full_name       first        last
# 0   21  abdolgader karimadini  abdolgader  karimadini
# 1   20   abdolaziz karimadini   abdolaziz  karimadini
# 2   38         ali karimadini         ali  karimadini
# 3  NaN                    NaN       vahid         NaN

# %%
people2={
    'first':['reza','narges'],
    'last':['karimadini','karimadini'],
    'age':['20','20']
}
dpeople2=pd.DataFrame(people2)

# %%
dpeople=dpeople.append(dpeople2,ignore_index=True)

# %%
dpeople
# Out:
#   age              full_name       first        last
# 0  21  abdolgader karimadini  abdolgader  karimadini
# 1  20   abdolaziz karimadini   abdolaziz  karimadini
# 2  38         ali karimadini         ali  karimadini
# 3  20                    NaN        reza  karimadini
# 4  20                    NaN      narges  karimadini

# %%
#dpeople.drop(index=4,inplace=True)
dpeople
# Out:
#   age              full_name       first        last
# 0  21  abdolgader karimadini  abdolgader  karimadini
# 1  20   abdolaziz karimadini   abdolaziz  karimadini
# 2  38         ali karimadini         ali  karimadini
# 3  20                    NaN        reza  karimadini
# 4  20                    NaN      narges  karimadini

# %%
filt6=dpeople['first']=='ali'
#dpeople.drop(index=dpeople[dpeople['first']=='ali'].index)
dpeople.drop(index=dpeople[filt6].index)
#dpeople.drop(index=dpeople[filt6].index,inplace=True)
#dpeople.drop(index=dpeople[dpeople['first']=='ali'].index,inplace=True)
# Out:
#   age              full_name       first        last
# 0  21  abdolgader karimadini  abdolgader  karimadini
# 1  20   abdolaziz karimadini   abdolaziz  karimadini
# 3  20                    NaN        reza  karimadini
# 4  20                    NaN      narges  karimadini

# %%
dpeople
# Out:
#   age              full_name       first        last
# 0  21  abdolgader karimadini  abdolgader  karimadini
# 1  20   abdolaziz karimadini   abdolaziz  karimadini
# 2  38         ali karimadini         ali  karimadini
# 3  20                    NaN        reza  karimadini
# 4  20                    NaN      narges  karimadini

# %%
dpeople.sort_values(by='first',ascending=False)#sorts the data according to the column first in the alphadamatic order
# Out:
#   age              full_name       first        last
# 3  20                    NaN        reza  karimadini
# 4  20                    NaN      narges  karimadini
# 2  38         ali karimadini         ali  karimadini
# 0  21  abdolgader karimadini  abdolgader  karimadini
# 1  20   abdolaziz karimadini   abdolaziz  karimadini

# %%
dpeople.sort_values(by=['first','age'],ascending=False)
# Out:
#   age              full_name       first        last
# 3  20                    NaN        reza  karimadini
# 4  20                    NaN      narges  karimadini
# 2  38         ali karimadini         ali  karimadini
# 0  21  abdolgader karimadini  abdolgader  karimadini
# 1  20   abdolaziz karimadini   abdolaziz  karimadini

# %%
dpeople.sort_values(by=['first','full_name'],ascending=[False,True])
#dpeople.sort_values(by=['first','full_name'],ascending=[False,True],inplace=True)
# Out:
#   age              full_name       first        last
# 3  20                    NaN        reza  karimadini
# 4  20                    NaN      narges  karimadini
# 2  38         ali karimadini         ali  karimadini
# 0  21  abdolgader karimadini  abdolgader  karimadini
# 1  20   abdolaziz karimadini   abdolaziz  karimadini

# %%
dpeople
# Out:
#   age              full_name       first        last
# 0  21  abdolgader karimadini  abdolgader  karimadini
# 1  20   abdolaziz karimadini   abdolaziz  karimadini
# 2  38         ali karimadini         ali  karimadini
# 3  20                    NaN        reza  karimadini
# 4  20                    NaN      narges  karimadini

# %%
dpeople.sort_index()
# Out:
#   age              full_name       first        last
# 0  21  abdolgader karimadini  abdolgader  karimadini
# 1  20   abdolaziz karimadini   abdolaziz  karimadini
# 2  38         ali karimadini         ali  karimadini
# 3  20                    NaN        reza  karimadini
# 4  20                    NaN      narges  karimadini

# %%
data.sort_values(by=['Country','salaryUSD'],ascending=[True,False],inplace=True)
data['Country'].head(50)
# Out:
# Respondent
# 63129    Afghanistan
# 50499    Afghanistan
# 39258    Afghanistan
# 58450    Afghanistan
# 7085     Afghanistan
# 22450    Afghanistan
# 48436    Afghanistan
# 10746    Afghanistan
# 8149     Afghanistan
# 29736    Afghanistan
# 722      Afghanistan
# 28638    Afghanistan
# 6417     Afghanistan
# 7353     Afghanistan
# 12310    Afghanistan
# 26340    Afghanistan
# 29045    Afghanistan
# 33178    Afghanistan
# 37802    Afghanistan
# 40000    Afghanistan
# 43106    Afghanistan
# 44403    Afghanistan
# 45854    Afghanistan
# 47110    Afghanistan
# 49702    Afghanistan
# 50767    Afghanistan
# 51859    Afghanistan
# 58760    Afghanistan
# 59560    Afghanistan
# 60569    Afghanistan
# 60946    Afghanistan
# 62168    Afghanistan
# 62525    Afghanistan
# 74386    Afghanistan
# 80926    Afghanistan
# 85715    Afghanistan
# 85825    Afghanistan
# 86362    Afghanistan
# 86932    Afghanistan
# 87091    Afghanistan
# 88582    Afghanistan
# 88731    Afghanistan
# ...

# %%
data[['Country','salaryUSD']].head(50)
# Out:
#                 Country  salaryUSD
# Respondent
# 63129       Afghanistan  1000000.0
# 50499       Afghanistan   153216.0
# 39258       Afghanistan    19152.0
# 58450       Afghanistan    17556.0
# 7085        Afghanistan    14364.0
# 22450       Afghanistan     7980.0
# 48436       Afghanistan     4464.0
# 10746       Afghanistan     3996.0
# 8149        Afghanistan     1596.0
# 29736       Afghanistan     1116.0
# 722         Afghanistan        0.0
# 28638       Afghanistan        0.0
# 6417        Afghanistan        NaN
# 7353        Afghanistan        NaN
# 12310       Afghanistan        NaN
# 26340       Afghanistan        NaN
# 29045       Afghanistan        NaN
# 33178       Afghanistan        NaN
# 37802       Afghanistan        NaN
# 40000       Afghanistan        NaN
# 43106       Afghanistan        NaN
# 44403       Afghanistan        NaN
# 45854       Afghanistan        NaN
# 47110       Afghanistan        NaN
# 49702       Afghanistan        NaN
# ...

# %%
data['salaryUSD'].nlargest(10)
# Out:
# Respondent
# 25983    2000000.0
# 87896    2000000.0
# 22013    2000000.0
# 28243    2000000.0
# 72732    2000000.0
# 78151    2000000.0
# 80200    2000000.0
# 52132    2000000.0
# 75561    2000000.0
# 32250    2000000.0
# Name: salaryUSD, dtype: float64

# %%
data.nlargest(10,'salaryUSD')
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 25983                          I am a developer by profession     true
# 87896                          I am a developer by profession     true
# 22013                          I am a developer by profession     true
# 28243                          I am a developer by profession     true
# 72732       I am not primarily a developer, but I write co...    false
# 78151                          I am a developer by profession     true
# 80200                          I am a developer by profession     true
# 52132                          I am a developer by profession     true
# 75561                          I am a developer by profession     true
# 32250                          I am a developer by profession     true
#
#                                                   OpenSourcer  \
# Respondent
# 25983                                 Less than once per year
# ...

# %%
data['salaryUSD'].median()#ignores the NaN
# Out:
# 57287.0

# %%
data.median()#searches the whole df and finds the columns with numrical values
# Out:
# CompTotal      62000.0
# salaryUSD      57287.0
# WorkWeekHrs       40.0
# CodeRevHrs         4.0
# Age               29.0
# dtype: float64

# %%
data['salaryUSD'].count()#number of people who answered the question
# Out:
# 55823

# %%
data['Hobbyist'].value_counts()
# Out:
# true     71257
# false    17626
# Name: Hobbyist, dtype: int64

# %%
data['SocialMedia'].value_counts(normalize=True)#-->persentage
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %%
data['SocialMedia'].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %%
data['Country'].value_counts()
# Out:
# United States            20949
# India                     9061
# Germany                   5866
# United Kingdom            5737
# Canada                    3395
#                          ...
# Niger                        1
# Timor-Leste                  1
# Saint Kitts and Nevis        1
# Tonga                        1
# Sao Tome and Principe        1
# Name: Country, Length: 179, dtype: int64

# %%
data.groupby(['Country'])

# %%
country_gp=data.groupby(['Country'])

# %%
country_gp.get_group('United States')#gets all the df for united states
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 58          I am a developer by profession     true
# 102         I am a developer by profession    false
# 166         I am a developer by profession     true
# 436         I am a developer by profession     true
# 452         I am a developer by profession     true
# ...                                    ...      ...
# 78292                                  NaN    false
# 82717                                  NaN    false
# 83397                                  NaN     true
# 85642                                  NaN    false
# 88282                                  NaN     true
#
#                            OpenSourcer  \
# Respondent
# 58          Once a month or more often
# 102                              Never
# 166            Less than once per year
# 436            Less than once per year
# 452                              Never
# ...                                ...
# ...

# %%
filt12=data['Country']=='United States'
data[filt12]['SocialMedia'].value_counts()#only for united states
# Out:
# Reddit                      5700
# Twitter                     3468
# Facebook                    2844
# YouTube                     2463
# I don't use social media    1851
# Instagram                   1652
# LinkedIn                    1020
# WhatsApp                     609
# Snapchat                     326
# WeChat 微信                     93
# VK ВКонта́кте                  9
# Weibo 新浪微博                     8
# Hello                          2
# Youku Tudou 优酷                 1
# Name: SocialMedia, dtype: int64

# %%
country_gp['SocialMedia'].value_counts().head(50)#the index is country
# Out:
# Country              SocialMedia
# Afghanistan          Facebook                     15
#                      YouTube                       9
#                      I don't use social media      6
#                      WhatsApp                      4
#                      Instagram                     1
#                      LinkedIn                      1
#                      Twitter                       1
# Albania              WhatsApp                     18
#                      Facebook                     16
#                      Instagram                    13
#                      YouTube                      10
#                      Twitter                       8
#                      LinkedIn                      7
#                      Reddit                        6
#                      I don't use social media      4
#                      Snapchat                      1
#                      WeChat 微信                     1
# ...

# %%
country_gp['SocialMedia'].value_counts().loc['India']
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
country_gp['SocialMedia'].value_counts(normalize=True).loc['India']
# Out:
# SocialMedia
# WhatsApp                    0.342379
# YouTube                     0.208405
# LinkedIn                    0.109355
# Facebook                    0.096301
# Instagram                   0.094126
# Twitter                     0.062063
# Reddit                      0.054162
# I don't use social media    0.028627
# Snapchat                    0.002634
# Hello                       0.000573
# WeChat 微信                   0.000573
# VK ВКонта́кте               0.000458
# Youku Tudou 优酷              0.000229
# Weibo 新浪微博                  0.000115
# Name: SocialMedia, dtype: float64

# %%
country_gp['salaryUSD'].median()
# Out:
# Country
# Afghanistan                               6222.0
# Albania                                  10818.0
# Algeria                                   7878.0
# Andorra                                 160931.0
# Angola                                    7764.0
#                                           ...
# Venezuela, Bolivarian Republic of...      6384.0
# Viet Nam                                 11892.0
# Yemen                                    11940.0
# Zambia                                    5040.0
# Zimbabwe                                 19200.0
# Name: salaryUSD, Length: 179, dtype: float64

# %%
country_gp['salaryUSD'].median().loc['United States']
# Out:
# 110000.0

# %%
country_gp['salaryUSD'].agg(['median','mean'])#aggrigation-->can choose which ones you need
# Out:
#                                         median           mean
# Country
# Afghanistan                             6222.0  101953.333333
# Albania                                10818.0   21833.700000
# Algeria                                 7878.0   34924.047619
# Andorra                               160931.0  160931.000000
# Angola                                  7764.0    7764.000000
# ...                                        ...            ...
# Venezuela, Bolivarian Republic of...    6384.0   14581.627907
# Viet Nam                               11892.0   17233.436782
# Yemen                                  11940.0   16909.166667
# Zambia                                  5040.0   10075.375000
# Zimbabwe                               19200.0   34046.666667
#
# [179 rows x 2 columns]

# %%
country_gp['salaryUSD'].agg(['median','mean']).loc['Canada']
# Out:
# median     68705.000000
# mean      134018.564909
# Name: Canada, dtype: float64

# %%
filt12=data['Country']=='United States'
data[filt12]['LanguageWorkedWith'].str.contains('Python')
# Out:
# Respondent
# 58       False
# 102      False
# 166      False
# 436       True
# 452      False
#          ...
# 78292     True
# 82717      NaN
# 83397     True
# 85642    False
# 88282    False
# Name: LanguageWorkedWith, Length: 20949, dtype: object

# %%
filt12=data['Country']=='India'
data[filt12]['LanguageWorkedWith'].str.contains('Python').sum()#gives how many worked with python
# Out:
# 3105

# %%
country_gp['LanguageWorkedWith'].apply(lambda x:x.str.contains('Python').sum())#applies the function for every series
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
country_python=country_gp['LanguageWorkedWith'].apply(lambda x:x.str.contains('Python').sum())
country_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
country_responded=data['Country'].value_counts()
country_responded
# Out:
# United States            20949
# India                     9061
# Germany                   5866
# United Kingdom            5737
# Canada                    3395
#                          ...
# Niger                        1
# Timor-Leste                  1
# Saint Kitts and Nevis        1
# Tonga                        1
# Sao Tome and Principe        1
# Name: Country, Length: 179, dtype: int64

# %%
df=pd.concat([country_responded,country_python],axis='columns',sort=False)#-->concat is for combining 2 groups
df
# Out:
#                        Country  LanguageWorkedWith
# United States            20949               10083
# India                     9061                3105
# Germany                   5866                2451
# United Kingdom            5737                2384
# Canada                    3395                1558
# ...                        ...                 ...
# Niger                        1                   1
# Timor-Leste                  1                   1
# Saint Kitts and Nevis        1                   0
# Tonga                        1                   0
# Sao Tome and Principe        1                   1
#
# [179 rows x 2 columns]

# %%
df.rename(columns={'Country':'num_respondents','LanguageWorkedWith':'numknowspython'},inplace=True)
df
# Out:
#                        num_respondents  numknowspython
# United States                    20949           10083
# India                             9061            3105
# Germany                           5866            2451
# United Kingdom                    5737            2384
# Canada                            3395            1558
# ...                                ...             ...
# Niger                                1               1
# Timor-Leste                          1               1
# Saint Kitts and Nevis                1               0
# Tonga                                1               0
# Sao Tome and Principe                1               1
#
# [179 rows x 2 columns]

# %%
#percentage=(singe/whole)*100
df['pct_knows_python']=(df['numknowspython']/df['num_respondents'])*100
df
# Out:
#                        num_respondents  numknowspython  pct_knows_python
# United States                    20949           10083         48.131176
# India                             9061            3105         34.267741
# Germany                           5866            2451         41.783157
# United Kingdom                    5737            2384         41.554820
# Canada                            3395            1558         45.891016
# ...                                ...             ...               ...
# Niger                                1               1        100.000000
# Timor-Leste                          1               1        100.000000
# Saint Kitts and Nevis                1               0          0.000000
# Tonga                                1               0          0.000000
# Sao Tome and Principe                1               1        100.000000
#
# [179 rows x 3 columns]

# %%
df.sort_values(by='pct_knows_python',ascending=False,inplace=True)

# %%
df.head(50)
# Out:
#                                   num_respondents  numknowspython  \
# Sao Tome and Principe                           1               1
# Timor-Leste                                     1               1
# Niger                                           1               1
# Dominica                                        1               1
# Turkmenistan                                    7               6
# Mauritania                                      7               5
# Guinea                                          3               2
# Bahamas                                         3               2
# Guyana                                          3               2
# Uganda                                         72              47
# Iceland                                        49              30
# Haiti                                           5               3
# Namibia                                         5               3
# ...

# %%
df.loc['Iran']
# Out:
# num_respondents     738.000000
# numknowspython      268.000000
# pct_knows_python     36.314363
# Name: Iran, dtype: float64
